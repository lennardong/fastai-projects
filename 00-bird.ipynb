# %%
# !pip install -Uqq duckduckgo_search

# %%
## fastbook, fastai, fastcore
## fastai-projects/00-bird.ipynb
import fastbook as fb
import fastai.vision as fav
import fastai as fa
import fastcore as fc
import fastdownload as fd

import duckduckgo_search as ddg

# %%
def search_images(term, max_images=200): 
    return L(ddg.ddg_images(term, max_results=max_images)).itemgot('image')

# %%
dest = './00_data/bird.jpg'

im = fav.image.open_image(dest)
im.to_thumb(128, 128)
